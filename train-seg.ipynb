# %%
DATA_DIR = '/kaggle/input/b-dataset'

# %%
# !pip install ultralytics

# %%
import os

from ultralytics import YOLO


model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/kaggle/input/b-dataset/config.yaml', epochs=500, patience=0, batch=4, imgsz=720)

# %%
# !cd /kaggle/working
# !tar -czvf my_work_seg_bun.zip -C . .
